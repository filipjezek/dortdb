# %%
# %load_ext autoreload
# %autoreload 2

from common import Benchmark, load_benchmark_query_times, plot_benchmark_query_times

benchmark = Benchmark('tpch')
DATABASES = [ 'dortdb', 'alasql', 'sqlite' ]

# plot_database_query_times(benchmark, DATABASES[0])
# plot_database_query_times(benchmark, DATABASES[1])
# plot_database_query_times(benchmark, DATABASES[2])
# There is no clear tendency in the query times with respect to query iterations, so we don't exclude any "warm-up" iterations.
# There are some outliers though, so we will use the median.

query_times = load_benchmark_query_times(benchmark, DATABASES)

# plot_benchmark_query_times(query_times, DATABASES, 'bar', fillna=False)
# plot_benchmark_query_times(query_times, DATABASES, 'line', fillna=False)
plot_benchmark_query_times(query_times, DATABASES, 'bar', fillna=True)
# plot_benchmark_query_times(query_times, DATABASES, 'line', fillna=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# dortdb [5.75133269e+03 5.59564270e+02 2.90551975e+02 4.53644773e+02
#  1.19617756e+03 1.18152752e+03 5.11489559e+03 5.83623394e+03
#  4.43669081e+04 8.31556994e+02 1.21591216e+03 1.54628066e+03
#  7.17551636e+02 1.05867004e+03 2.14390639e+03 1.21872485e+03
#  3.44570765e+03 4.44167489e+03 6.00000000e+06 9.59779436e+02
#  4.78130465e+03 1.07726563e+02]
# alasql [1.28094368e+04 7.11076203e+02 5.00791873e+02 6.00000000e+06
#  3.77912867e+03 1.28007107e+04 2.72067369e+03 4.58255808e+03
#  6.00000000e+06 3.65403581e+03 6.00000000e+06 1.33179496e+04
#  6.00000000e+06 1.35818697e+04 1.25201367e+04 1.58239048e+02
#  4.23191616e+04 6.93424525e+02 6.00000000e+06 6.00000000e+06
#  6.00000000e+06 1.35010769e+05]
# sqlite [1467.6382765   41.7582625  405.5300515   96.4777235  387.2686365
#   246.6809785  449.9357405  794.1347285 1032.198399   225.774373
# ...
